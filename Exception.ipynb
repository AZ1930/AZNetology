# %% [markdown]
# Задание 1
# Печатные газеты использовали свой формат дат для каждого выпуска.
# Для каждой газеты из списка напишите формат указанной даты для перевода в объект datetime:
# The Moscow Times - Wednesday, October 2, 2002
# The Guardian - Friday, 11.10.13
# Daily News - Thursday, 18 August 1977

# %%
#Задание 1
from datetime import datetime
The_Moscow_Times = 'Wednesday, October 2, 2002'
The_Guardian = 'Friday, 11.10.13'
Daily_News = 'Thursday, 18 August 1977'

The_Moscow_Times_datetime = datetime.strptime(The_Moscow_Times, '%A, %B %d, %Y')
The_Moscow_Times_datetime
The_Guardian_datetime = datetime.strptime(The_Guardian, '%A, %m.%d.%y')
The_Guardian_datetime
Daily_News_datetime = datetime.strptime(Daily_News, '%A, %d %B %Y')
Daily_News_datetime
# Out:
# datetime.datetime(1977, 8, 18, 0, 0)

# %% [markdown]
# Задание 2
# Дан поток дат в формате YYYY-MM-DD, в которых встречаются некорректные значения:
# stream = ['2018-04-02', '2018-02-29', '2018-19-02']
#
# Напишите функцию, которая проверяет эти даты на корректность.
# Т. е. для каждой даты возвращает True (дата корректна) или False (некорректная дата).

# %%
#Задание 2.
#формате YYYY-MM-DD - верный формат
def date_check():
    for i in range(len(stream)):
        try:
            datetime.strptime(stream[i], '%Y-%m-%d')
            print('"{}" {}'.format(stream[i], True))
        except:
            print('"{}"  {}'.format(stream[i], False))
    return 
# основная часть
stream = ['2018-04-02', '2018-02-29', '2018-19-02'] 
date_check()
# Out:
# "2018-04-02" True
# "2018-02-29"  False
# "2018-19-02"  False

# %% [markdown]
# Задание 3
# Напишите функцию date_range, которая возвращает список дат за период от start_date до end_date.
# Даты должны вводиться в формате YYYY-MM-DD.
# В случае неверного формата или при start_date > end_date должен возвращаться пустой список.

# %%
# Задание 3.
from datetime import timedelta
def date_check(day_):
    try:
        datetime.strptime(day_, '%Y-%m-%d')
        print('{}'.format(day_, True))
        
    except:
        print('{}'.format(day_, False))
        k = 0
        return k
def date_range(start_date,end_date):
    start_dt = datetime.strptime(start_date, '%Y-%m-%d')
    end_dt = datetime.strptime(end_date, '%Y-%m-%d')
    current_dt = start_dt
    while current_dt <= end_dt:
        print(current_dt.strftime('%Y-%m-%d'))
        current_dt += timedelta(days=1)
    return
# основная часть
k =0
start_date = input('Введите дату начала периода в формате YYYY-MM-DD ')
print('Дата начала ', start_date)
date_check(start_date)
if k == 0:
    print('пустой список')
else:    
    end_date = input('Введите дату окончания периода в формате YYYY-MM-DD')
    print('Дата окончания ', end_date)
    date_check(end_date)
    if start_date < end_date:
        date_range(start_date,end_date)    
    else:
        print([])
# Out:
# Введите дату начала периода в формате YYYY-MM-DD 2021-01-99
# Дата начала  2021-01-99
# 2021-01-99

# %%
{
 " клетки " : [
  {
   " cell_type " : " уценка " ,
   " метаданные " : {},
   " источник " : [
    " Задание 1 \ n " ,
    " Напишите функцию date_range, которая возвращает список дней между датами start_date и end_date. \ N " ,
    " Даты должны вводиться в формате ГГГГ-ММ-ДД ".
   ]
  },
  {
   " cell_type " : " код " ,
   " execution_count " : 5 ,
   " метаданные " : {},
   " выходы " : [],
   " источник " : [
    " from datetime import datetime "
   ]
  },
  {
   " cell_type " : " код " ,
   " execution_count " : 6 ,
   " метаданные " : {},
   " выходы " : [],
   " источник " : [
    " from datetime import timedelta "
   ]
  },
  {
   " cell_type " : " код " ,
   " execution_count " : 7 ,
   " метаданные " : {
    " scrolled " : правда
   },
   " выходы " : [
    {
     " имя " : "стандартный вывод " ,
     " output_type " : " поток " ,
     " текст " : [
      « 2018-01-01 \ n » ,
      « 2018-01-02 \ n » ,
      « 2018-01-03 \ n » ,
      « 2018-01-04 \ n » ,
      « 2018-01-05 \ n » ,
      « 2018-01-06 \ n » ,
      « 2018-01-07 \ n » ,
      « 2018-01-08 \ n » ,
      « 2018-01-09 \ n » ,
      « 2018-01-10 \ n »
     ]
    }
   ],
   " источник " : [
    " start_date = '2018-01-01' \ n " ,
    " end_date = '2018-01-10' \ n " ,
    " \ п " ,
    " def diff1 (): \ n " ,
    "     \" \ "\" которая возвращает список дней между датами start_date и end_date \ "\" \ "\ n " ,
    "     \ п " ,
    " start_date_dt = datetime.strptime (start_date, '% Y-% m-% d') \ n " ,
    " end_date_dt = datetime.strptime (end_date, '% Y-% m-% d') \ n " ,
    " \ п " ,
    " while start_date_dt <= end_date_dt: \ n " ,
    "     print (start_date_dt.strftime ('% Y-% m-% d')) \ n " ,
    "     \ п " ,
    "     start_date_dt + = timedelta (дни = 1) "
   ]
  },
  {
   " cell_type " : " код " ,
   " execution_count " : ноль ,
   " метаданные " : {},
   " выходы " : [],
   " источник " : [
    " Дополните функцию из первого задания проверкой на корректность дат. \ N " ,
    « В случае неверного формата или если start_date> end_date должен возвращаться пустой список ».
   ]
  },
  {
   " cell_type " : " код " ,
   " execution_count " : 182 ,
   " метаданные " : {
    " scrolled " : правда
   },
   " выходы " : [],
   " источник " : [
    " start_date = '2018-01-11' \ n " ,
    " end_date = '2018-01-10' \ n " ,
    " \ п " ,
    " def diff1 (): \ n " ,
    "     \" \ "\" которая возвращает список дней между датами start_date и end_date \ "\" \ "\ n " ,
    "     \ п " ,
    " start_date_dt = datetime.strptime (start_date, '% Y-% m-% d') \ n " ,
    " end_date_dt = datetime.strptime (end_date, '% Y-% m-% d') \ n " ,
    " diff = end_date_dt-start_date_dt \ n " ,
    " diff = diff.days \ n " ,
    " тип (разн.) \ п " ,
    " число = разн + 1 "
   ]
  },
  {
   " cell_type " : " код " ,
   " execution_count " : 183 ,
   " метаданные " : {},
   " выходы " : [
    {
     " data " : {
      " текст / обычный " : [
       " [] "
      ]
     },
     " execution_count " : 183 ,
     " метаданные " : {},
     " output_type " : " execute_result "
    }
   ],
   " источник " : [
    " [(end_date_dt - timedelta (days = x)). strftime ('% Y-% m-% d') для x в диапазоне (num), если end_date_dt> start_date_dt] "
   ]
  },
  {
   " cell_type " : " код " ,
   " execution_count " : 133 ,
   " метаданные " : {},
   " выходы " : [],
   " источник " : [
    " # Дан поток дат в формате YYYY-MM-DD, в которых встречаются некорректные значения: \ n " ,
    " stream = ['2018-04-02', '2018-02-29', '2018-19-02'] \ n " ,
    " \ п " ,
    " # Напишите функцию, которая проверяет эти даты на корректность. \ N " ,
    " # Т. Е. Для каждой возвращает возвращает True (дата корректна) False (некорректная дата). "
   ]
  },
  {
   " cell_type " : " код " ,
   " execution_count " : 137 ,
   " метаданные " : {
    " scrolled " : правда
   },
   " выходы " : [
    {
     " имя " : "стандартный вывод " ,
     " output_type " : " поток " ,
     " текст " : [
      " <класс 'str'> \ n " ,
      " <класс 'str'> \ n " ,
      " <класс 'str'> \ n "
     ]
    }
   ],
   " источник " : [
    " для каждого в потоке: \ n " ,
    "     печать (введите (каждый)) "
   ]
  },
  {
   " cell_type " : " код " ,
   " execution_count " : 138 ,
   " метаданные " : {},
   " выходы " : [
    {
     " имя " : "стандартный вывод " ,
     " output_type " : " поток " ,
     " текст " : [
      " ['2018-04-02', '2018-02-29', '2018-19-02'] \ n "
     ]
    }
   ],
   " источник " : [
    " stream_str = [] \ n " ,
    " для каждого в потоке: \ n " ,
    "     если тип (каждый) == 'datetime.datetime': \ n " ,
    "         stream_str.append (each.strftime ('% Y-% m-% d')) \ n " ,
    "     else: \ n " ,
    "         stream_str.append (каждый) \ n " ,
    " печать (stream_str) "
   ]
  },
  {
   " cell_type " : " код " ,
   " execution_count " : 144 ,
   " метаданные " : {},
   " выходы " : [
    {
     " data " : {
      " текст / обычный " : [
       " список "
      ]
     },
     " execution_count " : 144 ,
     " метаданные " : {},
     " output_type " : " execute_result "
    }
   ],
   " источник " : [
    " тип (stream_str) "
   ]
  },
  {
   " cell_type " : " код " ,
   " execution_count " : ноль ,
   " метаданные " : {},
   " выходы " : [],
   " источник " : [
    " from datetime import datetime \ n " ,
    " \ п " ,
    " def validate (date_text): \ n " ,
    "     попробуйте: \ n " ,
    "         if date_text! = datetime.strptime (date_text, \" % Y-% m-% d \ " ) .strftime ('% Y-% m-% d'): \ n " ,
    "             поднять ValueError \ n " ,
    "         вернуть True \ n " ,
    "     кроме ValueError: \ n " ,
    "         вернуть ложь "
   ]
  },
  {
   " cell_type " : " код " ,
   « execution_count » : 149 ,
   " метаданные " : {},
   " выходы " : [
    {
     " data " : {
      " текст / обычный " : [
       « [Верно, Ложно, Ложно] »
      ]
     },
     « execution_count » : 149 ,
     " метаданные " : {},
     " output_type " : " execute_result "
    }
   ],
   " источник " : [
    " список (карта (проверка, stream_str)) "
   ]
  },
  {
   " cell_type " : " код " ,
   " execution_count " : 31 ,
   " метаданные " : {
    " свернутый " : правда
   },
   " выходы " : [
    {
     " ename " : " SyntaxError " ,
     " evalue " : " недопустимый синтаксис (<ipython-input-31-c340623f54ba>, строка 1) " ,
     " output_type " : " ошибка " ,
     " трассировка " : [
      " \ u001b [1; 36м файл \ u001b [1; 32m \" <ipython-input-31-c340623f54ba> \ "\ u001b [1; 36м, строка \ u001b [1; 32m1 \ u001b [0m \ n \ u001b [ 1; 33m Напишите функцию, которая возвращает список дат с 1 по вчерашний день текущего месяца Если дан один день месяца, то возвращается список дней прошлого месяца.. \ u001b [0м \ п \ u001b [1; 37m ^ \ u001b [0м \ п \ u001b [1; 31mSyntaxError \ u001b [0m \ u001b [1; 31m: \ u001b [недопустимый синтаксис 0m \ n »
     ]
    }
   ],
   " источник " : [
    " Напишите функцию, которая возвращает список дат с 1 по вчерашний день текущего месяца. \ N " ,
    « Если дан 1 день месяца, то возвращается список дней прошлого месяца ».
   ]
  },
  {
   " cell_type " : " код " ,
   " execution_count " : 59 ,
   " метаданные " : {},
   " выходы " : [],
   " источник " : [
    " дата и время импорта "
   ]
  },
  {
   " cell_type " : " код " ,
   " execution_count " : 60 ,
   " метаданные " : {
    " прокрученный " : ложь
   },
   " выходы " : [
    {
     " имя " : "стандартный вывод " ,
     " output_type " : " поток " ,
     " текст " : [
      " 2019-05-01 \ n "
     ]
    }
   ],
   " источник " : [
    " TodayDate = datetime.date.today () \ n " ,
    " если TodayDate.day == 1: \ n " ,
    "     TodayDate - = timedelta (месяц = ​​1) \ n " ,
    "     StartDate = TodayDate.replace (day = 1) \ n " ,
    "     печать (Дата начала) \ n " ,
    " else: \ n " ,
    "     StartDate = TodayDate.replace (day = 1) \ n " ,
    "     печать (Дата начала) "
   ]
  },
  {
   " cell_type " : " код " ,
   " execution_count " : 61 ,
   " метаданные " : {},
   " выходы " : [
    {
     " имя " : "стандартный вывод " ,
     " output_type " : " поток " ,
     " текст " : [
      " 2019-05-01 \ n "
     ]
    }
   ],
   " источник " : [
    " печать (Дата начала) "
   ]
  },
  {
   " cell_type " : " код " ,
   " execution_count " : 62 ,
   " метаданные " : {
    " scrolled " : правда
   },
   " выходы " : [
    {
     " имя " : "стандартный вывод " ,
     " output_type " : " поток " ,
     " текст " : [
      « 2019-05-26 \ n »
     ]
    }
   ],
   " источник " : [
    " YestDate = datetime.date.today () - timedelta (days = 1) \ n " ,
    " печать (YestDate) "
   ]
  },
  {
   " cell_type " : " код " ,
   " execution_count " : 66 ,
   " метаданные " : {},
   " выходы " : [
    {
     " имя " : "стандартный вывод " ,
     " output_type " : " поток " ,
     " текст " : [
      " 26 \ n "
     ]
    }
   ],
   " источник " : [
    " difference_in_days = abs ((YestDate - StartDate) .days) \ n " ,
    " разница в_днях = разница в_днях +1 \ n " ,
    " печать (разница_в_дней) "
   ]
  },
  {
   " cell_type " : " код " ,
   " execution_count " : 67 ,
   " метаданные " : {},
   " выходы " : [
    {
     " имя " : "стандартный вывод " ,
     " output_type " : " поток " ,
     " текст " : [
      « [datetime.date (2019, 5, 26), datetime.date (2019, 5, 25), datetime.date (2019, 5, 24), datetime.date (2019, 5, 23), datetime.date ( 2019, 5, 22), datetime.date (2019, 5, 21), datetime.date (2019, 5, 20), datetime.date (2019, 5, 19), datetime.date (2019, 5, 18) , datetime.date (2019, 5, 17), datetime.date (2019, 5, 16), datetime.date (2019, 5, 15), datetime.date (2019, 5, 14), datetime.date (2019 , 5, 13), datetime.date (2019, 5, 12), datetime.date (2019, 5, 11), datetime.date (2019, 5, 10), datetime.date (2019, 5, 9), datetime.date (2019, 5, 8), datetime.date (2019, 5, 7), datetime.date (2019, 5, 6), datetime.date (2019, 5, 5), datetime.date (2019, 5, 4), datetime.date (2019, 5, 3), datetime.date (2019, 5, 2), datetime.date (2019, 5, 1)] \ n "
     ]
    }
   ],
   " источник " : [
    " YestDate = datetime.date.today () - timedelta (days = 1) \ n " ,
    "число дней = разница в_днях \ n " ,
    " dateList = [] \ n " ,
    " для x в диапазоне (0, число дней): \ n " ,
    "     dateList.append (YestDate - datetime.timedelta (days = x)) \ n " ,
    " печать (dateList) "
   ]
  }
 ],
 " метаданные " : {
  " kernelspec " : {
   " display_name " : " Python 3 " ,
   " язык " : " питон " ,
   " имя " : " питон3 "
  },
  " language_info " : {
   " codemirror_mode " : {
    " имя " : " ipython " ,
    « версия » : 3
   },
   " расширение_файла " : " .py " ,
   " mimetype " : " текст / x-python " ,
   " имя " : " питон " ,
   " nbconvert_exporter " : " питон " ,
   " pygments_lexer " : " ipython3 " ,
   " версия " : " 3.7.0 "
  }
 },
 « nbformat » : 4 ,
 " nbformat_minor " : 2
}
