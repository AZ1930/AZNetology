# %%
documents = [
 {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
 {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
 {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]
directories = {
 '1': ['2207 876234', '11-2'],
 '2': ['10006'],
 '3': []
}
# Функция 1
def p(doc_number):
    """ 1.Пользователь по команде "p" может узнать владельца документа по его номеру"""
    for i in range(len(documents)):
        k = documents[i]['number']
        if doc_number == k:
            res = documents[i]['name']
            break
        else:
            res = 'Документ не найден в базе'
    return res
# Функция 2
def s(doc_number_2):
    """2.Пользователь по команде "s" может по номеру документа узнать на какой полке он хранится"""
    for shelf, doc in directories.items():
        for i in range(len(doc)):
            if doc_number_2 == doc[i]:
                res_2 = shelf
            else:
                res_2 = 'Документ не найден в базе'
    return res_2
# Функция 3
def l():
    """3.Пользователь по команде "l" может увидеть полную информацию по всем документам"""
    for i in range(len(documents)):
        k = (documents[i])
        print('№: ',k['number'],', ', 'тип: ', k['type'],', владелец: ',k['name'],', полка хранения: ', s(doc_number_2 = k['number']))
    return k['number']
# Функция 4
def ads(new_shelf):
    """4.Пользователь по команде "ads" может добавить новую полку"""
    import copy
    directoriescopy = directories.copy()
    list_1 = list(directoriescopy)
    print(list_1)
    for key in range(len(list_1)):
        if new_shelf == directories.keys:
            print('Такая полка уже существует.Текущий перечень полок:',list(directoriescopy.keys()))
        else:
            directoriescopy[new_shelf] = ''
            print('Полка добавлена. Текущий перечень полок:',list(directoriescopy.keys()))
    return new_shelf
# Функция 5
def ds():
    """Пользователь по команде "ds" может удалить существующую полку из данных (только если она пустая)"""
    directoriescopy2 = directories.copy()
    print(directoriescopy2)
    for key in directories.keys():
        print('key =', key)
        if (directories[del_shelf] !=[] and del_shelf == key):
            print('На полке есть документы, удалите их перед удалением полки. Текущий перечень полок:',list(directoriescopy2.keys()))
        elif (directories[del_shelf] == [] and del_shelf == key):
            del(directoriescopy2[del_shelf])
            print('Полка удалена. Текущий перечень полок:',list(directoriescopy2.keys()))
        else:
            print('Такой полки не существует. Текущий перечень полок: ',list(directoriescopy2.keys()))
            
    return del_shelf
    
command = ''    
# Основная часть
while command != 'q':
    command = input('Введите команду: ')
    if command == 'p':
        doc_number = (input('Введите номер документа: '))
        p(doc_number)
        print('Владелец документа:', p(doc_number))  
    elif command == 's':
        doc_number_2 = (input('Введите номер документа: '))
        s(doc_number_2)
        print('Документ лежит на полке:', s(doc_number_2))
    elif command == 'l':
        print('Ваше инфо:')
        l()
    elif command == 'ads':
        new_shelf = input('Введите номер полки: ')
        ads(new_shelf)
    elif command == 'ds':
        del_shelf = str(input('Введите номер полки: '))
        ds()
        
    elif command == 'q':
        print('Выход из программы')
        break
        
    else:
        print('Не та команда ')
# Out:
# Введите команду: q
# Выход из программы
